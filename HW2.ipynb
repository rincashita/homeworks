# %%
#создаем переменную
text= """"варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг"""

#с помощью команды split считаем кол-во слов и выодим 
word= text.split()
bigrams = []
print(word)

#задаем цикл по созданию списка биграмм
for i in range(len(word)-1):
    bigrams.append([word[i],word[i+1]])
print(bigrams)
# Out:
# ['"варкалось', 'хливкие', 'шорьки', 'пырялись', 'по', 'наве', 'и', 'хрюкотали', 'зелюки', 'как', 'мюмзики', 'в', 'мове', 'о', 'бойся', 'бармаглота', 'сын', 'он', 'так', 'свирлеп', 'и', 'дик', 'а', 'в', 'глyще', 'рымит', 'исполин', 'злопастный', 'брандашмыг']
# [['"варкалось', 'хливкие'], ['хливкие', 'шорьки'], ['шорьки', 'пырялись'], ['пырялись', 'по'], ['по', 'наве'], ['наве', 'и'], ['и', 'хрюкотали'], ['хрюкотали', 'зелюки'], ['зелюки', 'как'], ['как', 'мюмзики'], ['мюмзики', 'в'], ['в', 'мове'], ['мове', 'о'], ['о', 'бойся'], ['бойся', 'бармаглота'], ['бармаглота', 'сын'], ['сын', 'он'], ['он', 'так'], ['так', 'свирлеп'], ['свирлеп', 'и'], ['и', 'дик'], ['дик', 'а'], ['а', 'в'], ['в', 'глyще'], ['глyще', 'рымит'], ['рымит', 'исполин'], ['исполин', 'злопастный'], ['злопастный', 'брандашмыг']]

# %%
# импортируем модуль
import os      

# посмотрим, в какой папке мы находимся
print(os.getcwd())

# выводим список файлов и папок внутри нее

for file in os.listdir('.'): # точка = текущая папка
    print(file)
    
    # указываем путь к папке на моем компьютере и печатаем все, что хранится
for root, dirs, files in os.walk('C:\\Users\\User\\Desktop\\python-dh-hw'):
    print(root)
    print(dirs)
    for name in files:
        fullname = os.path.join(root, name)
        print(fullname)
        
        # Создаем цикл для рабочей директории,который читает содержимое каждого файла и записывает его в новый файл poems.txt 
os.chdir(r'C:\\Users\\User\\Desktop\\python-dh-hw\\poems') #2
for root, dirs, files in os.walk('.'): #2
    print (dirs) #2
    print (files) #2
    print(len(files)) #2
    
    with open('poems.txt','w',encoding='utf-8') as f:
     for root, dirs, files in os.walk('.'):
        for file in files:
            if os.path.exists(file):
                with open(file,'r',encoding='utf-8') as name:
                    name=name.read()
                    f.write(name+ '\n')
            elif os.path.exists('.\котики\%s' %file):
                with open('.\котики\%s' %file,'r',encoding='utf-8') as name:
                    name=name.read()
                    f.write(name+ '\n')
            elif os.path.exists('.\сказки\%s' %file):
                with open('.\сказки\%s' %file,'r',encoding='utf-8') as name:
                    name=name.read()
                    f.write(name+ '\n')
with open ('poems.txt','r',encoding='utf-8') as q:
    print (q.read())
# Out:
# C:\Users\User\Desktop\python-dh-hw\poems
# poems.txt
# боль.txt
# ворон.txt
# деды.txt
# кладь.txt
# котики
# ночь.txt
# сказки
# шредингер.txt
# C:\Users\User\Desktop\python-dh-hw
# C:\Users\User\Desktop\python-dh-hw\poems\сказки\королевич.txt
# C:\Users\User\Desktop\python-dh-hw\poems\сказки\король.txt
# C:\Users\User\Desktop\python-dh-hw\poems\сказки\крестная.txt
# C:\Users\User\Desktop\python-dh-hw\poems\сказки\яга.txt
# ['котики', 'сказки']
# ['poems.txt', 'боль.txt', 'ворон.txt', 'деды.txt', 'кладь.txt', 'ночь.txt', 'шредингер.txt']
# 7
# []
# ['кот.txt', 'лео.txt', 'пушок.txt']
# 3
# []
# ['гримм.txt', 'королевич.txt', 'король.txt', 'крестная.txt', 'яга.txt']
# 5
#
# а боль у вас какого рода
# спросил дежурный врач а я
# как на духу она ответил
# моя
# американский чорный ворон
# как наш красив и голосист
# но попроси не виться сразу
# расист
# на спиритическом сеансе
# желая водки и еды
# привычно вызывали духов
# деды
# мы б вас охотно пропустили
# с ручною кладью но пока
# она у вас недопустимо
# дика
# ночь улица фонарь аптека
# вдруг вспомнил что утюг включон
# акетпа ираноф ацилу
# и ьчон
# приходит муж домой пораньше
# измену в нём предположив
# а шрёдингер в шкафу не мёртв и
# не жив
# кот по цепи идёт направо
# и упирается в щиток
# а от щитка идя налево
# он ток
# загримирован под медведя
# кот гнал ди каприо по льду
# и все кричали оскар лео
# польду
# пушок пушок кричит хозяйка
# а мы сидим невдалеке
# и ухмыляемся а рыльца
# в пушке
# идут по лесу братья гриммы
# и вырубают топором
# всех тех кто был уже написан
# перром
# третьеразрядный королевич
# побил дракона как герой
# царевну вызволил и сдал на
# второй
# на платье новое дивится
# и восторгается страна
# вдруг кто то крикнул а король то
# она
# а если принц тебя обидит
# поверь тогда ему конец
# ведь я не крёстная а крёстный
# отец
# клюку на рынке выбирая
# яга сказала дайте две
# я кэмээс по скандинавской
# ходьбе

# %%
text= """Несчастная кошка порезала лапу-
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!"""

letters = list(text)  # разбивает строку на минимальные элементы, т.е. посимвольно
print(letters)
print(len(text)) # №2


# выводим слова без знаков препинания
from string import punctuation

words = text.split()
words = [w.strip(punctuation) for w in words]
print(words) # №3
new_string = ""
for w in words:
    new_string += (w + " ")
print (new_string) # №4

print ([word.lower() if w.istitle() else word for word in words]) # №5

print (len(words)) # № 6

print (len([word for word in words if words.count (word) == 1])) # №7

print (words [-10:0]) # №8
# Out:
# ['Н', 'е', 'с', 'ч', 'а', 'с', 'т', 'н', 'а', 'я', ' ', 'к', 'о', 'ш', 'к', 'а', ' ', 'п', 'о', 'р', 'е', 'з', 'а', 'л', 'а', ' ', 'л', 'а', 'п', 'у', '-', '\n', 'С', 'и', 'д', 'и', 'т', ',', ' ', 'и', ' ', 'н', 'и', ' ', 'ш', 'а', 'г', 'у', ' ', 'н', 'е', ' ', 'м', 'о', 'ж', 'е', 'т', ' ', 'с', 'т', 'у', 'п', 'и', 'т', 'ь', '.', '\n', 'С', 'к', 'о', 'р', 'е', 'й', ',', ' ', 'ч', 'т', 'о', 'б', 'ы', ' ', 'в', 'ы', 'л', 'е', 'ч', 'и', 'т', 'ь', ' ', 'к', 'о', 'ш', 'к', 'и', 'н', 'у', ' ', 'л', 'а', 'п', 'у', '\n', 'В', 'о', 'з', 'д', 'у', 'ш', 'н', 'ы', 'е', ' ', 'ш', 'а', 'р', 'и', 'к', 'и', ' ', 'н', 'а', 'д', 'о', ' ', 'к', 'у', 'п', 'и', 'т', 'ь', '!', '\n', '\n', 'И', ' ', 'с', 'р', 'а', 'з', 'у', ' ', 'с', 'т', 'о', 'л', 'п', 'и', 'л', 'с', 'я', ' ', 'н', 'а', 'р', 'о', 'д', ' ', 'н', 'а', ' ', 'д', 'о', 'р', 'о', 'г', 'е', '-', '\n', 'Ш', 'у', 'м', 'и', 'т', ',', ' ', 'и', ' ', 'к', 'р', 'и', 'ч', 'и', 'т', ',', ' ', 'и', ' ', 'н', 'а', ' ', 'к', 'о', 'ш', 'к', 'у', ' ', 'г', 'л', 'я', 'д', 'и', 'т', '.', '\n', 'А', ' ', 'к', 'о', 'ш', 'к', 'а', ' ', 'о', 'т', 'ч', 'а', 'с', 'т', 'и', ' ', 'и', 'д', 'е', 'т', ' ', 'п', 'о', ' ', 'д', 'о', 'р', 'о', 'г', 'е', ',', '\n', 'О', 'т', 'ч', 'а', 'с', 'т', 'и', ' ', 'п', 'о', ' ', 'в', 'о', 'з', 'д', 'у', 'х', 'у', ' ', 'п', 'л', 'а', 'в', 'н', 'о', ' ', 'л', 'е', 'т', 'и', 'т', '!']
# 269
# ['Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']
# Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит
# ['Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']
# 44
# 31
# []
